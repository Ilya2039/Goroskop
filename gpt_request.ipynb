# %%
from google import genai

# Укажите ваш API-ключ
client = genai.Client(api_key="AIzaSyCqE4taBEs1GJUh_pJQUqdGgcSEfGL8Pbc")

# Выполните запрос к Gemini API
response = client.models.generate_content(
    model="gemini-2.0-flash-exp",
    contents="Меня зовут Илья, я родился 9 марта 2002 в 16:15 в Москве в России, дай мне мою натальную карту"
)

# Печать результата
print(response.text)
# Out:
# Хорошо, Илья. Вот твоя натальная карта, рассчитанная на основе введенных данных:
#
# **Основные данные:**
#
# *   **Имя:** Илья
# *   **Дата рождения:** 9 марта 2002 г.
# *   **Время рождения:** 16:15
# *   **Место рождения:** Москва, Россия
#
# **Положение планет в знаках зодиака:**
#
# *   **Солнце:** Рыбы
# *   **Луна:** Весы
# *   **Меркурий:** Водолей
# *   **Венера:** Водолей
# *   **Марс:** Козерог
# *   **Юпитер:** Рак
# *   **Сатурн:** Близнецы
# *   **Уран:** Водолей
# *   **Нептун:** Водолей
# *   **Плутон:** Стрелец
# *   **Северный узел:** Близнецы
# *   **Лилит (Черная Луна):** Козерог
#
# **Дома в гороскопе (Асцендент и куспиды домов):**
#
# *   **Асцендент:** Рак
# *   **2-й дом:** Лев
# *   **3-й дом:** Дева
# *   **4-й дом:** Весы
# *   **5-й дом:** Скорпион
# *   **6-й дом:** Стрелец
# *   **7-й дом:** Козерог
# *   **8-й дом:** Водолей
# *   **9-й дом:** Рыбы
# *   **10-й дом:** Овен
# *   **11-й дом:** Телец
# *   **12-й дом:** Близнецы
#
# ...
